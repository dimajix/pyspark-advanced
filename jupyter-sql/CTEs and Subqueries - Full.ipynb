# %% [markdown]
# # SQL Common Table Expressions
#
# SQl is a very powerful language that allows the construction of very complex queries. But SQL only provides very limited support for structuting query in order to increase readability. So called "Common Table Expressions" (CTEs) are a common way to split up large SQL queries into smaller and more manageable chunks. This approach works with all SQL databases, not only with Spark SQL.
#
# **Attention!** In Spark, CTEs will be optimized away, such that there is no difference in execution speed. Different (relational) databases might handle CTEs differently and they might represent an optimization barrier. Please consult the manual of your database before blindlingly using CTEs!
#
# For this notebook, we will pick up the weather example and use Spark SQL to calculate some aggregates per year and country. We will not provide the most efficient implementation in order to make the whole structure more complicated to show the power of common table expressions.

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as f

if not 'spark' in locals():
    spark = SparkSession.builder \
        .master("local[*]") \
        .config("spark.driver.memory","4G") \
        .getOrCreate()

spark
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/pyspark/bin/load-spark-env.sh: line 68: ps: command not found
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/11/13 17:12:36 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://fe49fe119e4f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
storageLocation = "s3://dimajix-training/data/weather"
#storageLocation = "/dimajix/data/weather-noaa-sample"

# %% [markdown]
# # 1. Register Temp Views
#
# In a first step, we will load the input data via Spark. In order to use Spark SQL, we will also immediately register the loaded DataFrames as temp views.

# %% [markdown]
# ## 1.1 Load Raw Data
#
# Like before, we will load the raw measurement data and register it as a temp view called `raw_weather`.

# %%
from functools import reduce

# Read in all years, store them in an Python array
raw_weather_per_year = [spark.read.text(storageLocation + "/" + str(i)).withColumn("year", f.lit(i)) for i in range(2003,2020)]

# Union all years together
raw_weather = reduce(lambda l,r: l.union(r), raw_weather_per_year)                        

# Register Spark DataFrame as named temporary view called 'raw_weather'
raw_weather.createOrReplaceTempView("raw_weather")

# %%
# Display first 10 records
spark.sql("SELECT * FROM raw_weather LIMIT 10").toPandas()
# Out:
#                                                value  year
# 0  0494703160256242003010100003+55200-162717SY-MT...  2003
# 1  0228703160256242003010100174+55200-162730FM-16...  2003
# 2  044070316025624200301010053C+55200-162717FM-15...  2003
# 3  0071703160256242003010101009+55200-162717NSRDB...  2003
# 4  042770316025624200301010153C+55200-162717FM-15...  2003
# 5  0071703160256242003010102009+55200-162717NSRDB...  2003
# 6  046870316025624200301010253C+55200-162717FM-15...  2003
# 7  0071703160256242003010103009+55200-162717NSRDB...  2003
# 8  041570316025624200301010353C+55200-162717FM-15...  2003
# 9  0054703160256242003010104009+55200-162717NSRDB...  2003

# %% [markdown]
# ## 2.2 Load Master Data
#
# Now we will load the stations master data and register a temp view called `stations`.

# %%
stations = spark.read.csv(storageLocation + "/isd-history", header=True)

# Display first 10 records    
stations.createOrReplaceTempView("stations")

# %%
# Display first 10 records
spark.sql("SELECT * FROM stations LIMIT 10").toPandas()
# Out:
#      USAF   WBAN STATION NAME  CTRY STATE  ICAO      LAT       LON  ELEV(M)
# 0  007018  99999   WXPOD 7018  None  None  None  +00.000  +000.000  +7018.0  \
# 1  007026  99999   WXPOD 7026    AF  None  None  +00.000  +000.000  +7026.0
# 2  007070  99999   WXPOD 7070    AF  None  None  +00.000  +000.000  +7070.0
# 3  008260  99999    WXPOD8270  None  None  None  +00.000  +000.000  +0000.0
# 4  008268  99999    WXPOD8278    AF  None  None  +32.950  +065.567  +1156.7
# 5  008307  99999   WXPOD 8318    AF  None  None  +00.000  +000.000  +8318.0
# 6  008411  99999         XM20  None  None  None     None      None     None
# 7  008414  99999         XM18  None  None  None     None      None     None
# 8  008415  99999         XM21  None  None  None     None      None     None
# 9  008418  99999         XM24  None  None  None     None      None     None
#
#       BEGIN       END
# 0  20110309  20130730
# 1  20120713  20170822
# 2  20140923  20150926
# 3  20050101  20100920
# 4  20100519  20120323
# 5  20100421  20100421
# 6  20160217  20160217
# 7  20160216  20160217
# 8  20160217  20160217
# 9  20160217  20160217

# %% [markdown]
# # 2. Using Intermediate Tables
#
# Let us first perform the weather analysis step by step using more intermediate temporary tables. Of course, this approach is very specific to Apache Spark and not directly available in other databases. But additional tools like [dbt](https://getdbt.com) will provide similar capabilities for generic SQL databases.

# %% [markdown]
# ## 2.1 Extract Measurements
#
# In the first step, we need to extract all the interesting attributes from the raw measurement data. We do this by using `substring` and approproiate casts and/or scaling.

# %%
query = """
    SELECT
        year,
        substring(value,5,6) AS usaf,
        substring(value,11,5) AS wban,
        substring(value,16,8) AS `date`,
        substring(value,24,4) AS `time`,
        substring(value,42,5) AS report_type,
        substring(value,61,3) AS wind_direction,
        substring(value,64,1) AS wind_direction_qual,
        substring(value,65,1) AS wind_observation,
        CAST(substring(value,66,4) AS FLOAT) / 10.0 AS wind_speed,
        substring(value,70,1) AS wind_speed_qual,
        CAST(substring(value,88,5) AS FLOAT) / 10.0 AS air_temperature,
        substring(value,93,1) AS air_temperature_qual
    FROM raw_weather
"""

# Create a Spark DataFrame for the SQL query above
weather = spark.sql(query)
# Register the DataFrame as a temp view with name 'weather'
weather.createOrReplaceTempView("weather")

# Display the first 10 records from the newly created temp view 'weather'
spark.sql("SELECT * FROM weather LIMIT 10").toPandas()
# Out:
#    year    usaf   wban      date  time report_type wind_direction
# 0  2003  703160  25624  20030101  0000       SY-MT            010  \
# 1  2003  703160  25624  20030101  0017       FM-16            020
# 2  2003  703160  25624  20030101  0053       FM-15            010
# 3  2003  703160  25624  20030101  0100       NSRDB            999
# 4  2003  703160  25624  20030101  0153       FM-15            010
# 5  2003  703160  25624  20030101  0200       NSRDB            999
# 6  2003  703160  25624  20030101  0253       FM-15            010
# 7  2003  703160  25624  20030101  0300       NSRDB            999
# 8  2003  703160  25624  20030101  0353       FM-15            020
# 9  2003  703160  25624  20030101  0400       NSRDB            999
#
#   wind_direction_qual wind_observation  wind_speed wind_speed_qual
# 0                   5                N         5.2               5  \
# 1                   1                N         4.6               1
# 2                   5                N         5.2               5
# 3                   9                9       999.9               9
# 4                   5                N         6.2               5
# 5                   9                9       999.9               9
# 6                   5                N         7.2               5
# 7                   9                9       999.9               9
# 8                   5                N         6.2               5
# 9                   9                9       999.9               9
#
#    air_temperature air_temperature_qual
# 0             -0.6                    5
# 1             -2.0                    1
# 2             -2.8                    5
# 3            999.9                    9
# 4             -2.2                    5
# 5            999.9                    9
# 6             -3.3                    5
# 7            999.9                    9
# 8             -1.1                    5
# 9            999.9                    9

# %% [markdown]
# ## 2.2 Join Data
#
# In the next step, we join the extracted measurement data with the stations master data. We use the two columns `usaf` and `wban` for joining. Since the join represents an enrichment of the measurements, we chose a *left join*. In order to access the extracted measurements, we can simply use the `weather` temp view we just created above.

# %%
query = """
    SELECT
        weather.*,
        CTRY AS country
    FROM weather
    LEFT JOIN stations ON weather.usaf = stations.usaf AND weather.wban = stations.wban
"""

# Create a Spark DataFrame for the SQL query above
joined_weather = spark.sql(query)
# Register the DataFrame as a temp view with name 'joined_weather'
joined_weather.createOrReplaceTempView("joined_weather")

# Display first 10 records from the newly created temp view 'joined_weather'
spark.sql("SELECT * FROM joined_weather LIMIT 10").toPandas()
# Out:
#    year    usaf   wban      date  time report_type wind_direction
# 0  2003  703160  25624  20030101  0000       SY-MT            010  \
# 1  2003  703160  25624  20030101  0017       FM-16            020
# 2  2003  703160  25624  20030101  0053       FM-15            010
# 3  2003  703160  25624  20030101  0100       NSRDB            999
# 4  2003  703160  25624  20030101  0153       FM-15            010
# 5  2003  703160  25624  20030101  0200       NSRDB            999
# 6  2003  703160  25624  20030101  0253       FM-15            010
# 7  2003  703160  25624  20030101  0300       NSRDB            999
# 8  2003  703160  25624  20030101  0353       FM-15            020
# 9  2003  703160  25624  20030101  0400       NSRDB            999
#
#   wind_direction_qual wind_observation  wind_speed wind_speed_qual
# 0                   5                N         5.2               5  \
# 1                   1                N         4.6               1
# 2                   5                N         5.2               5
# 3                   9                9       999.9               9
# 4                   5                N         6.2               5
# 5                   9                9       999.9               9
# 6                   5                N         7.2               5
# 7                   9                9       999.9               9
# 8                   5                N         6.2               5
# 9                   9                9       999.9               9
#
#    air_temperature air_temperature_qual country
# 0             -0.6                    5      US
# 1             -2.0                    1      US
# 2             -2.8                    5      US
# 3            999.9                    9      US
# 4             -2.2                    5      US
# 5            999.9                    9      US
# 6             -3.3                    5      US
# 7            999.9                    9      US
# 8             -1.1                    5      US
# 9            999.9                    9      US

# %% [markdown]
# ## 2.3 Aggregate Temperature
#
# We now aggregate the min, max and average air temperature per country and year. We will use a simple `WHERE` condition to ignore all records with invalid air temperature. Of course, we remember a more efficient overall solution. In order to make the example more complicated, we chose to ignore the simpler solution.

# %%
query = """
    SELECT
        year,
        country,
        min(air_temperature) AS min_air_temperature,
        max(air_temperature) AS max_air_temperature,
        avg(air_temperature) AS avg_air_temperature
    FROM joined_weather
    WHERE air_temperature_qual = '1'
    GROUP BY year,country
"""

# Create a Spark DataFrame for the SQL query above and register it as a temp view called 'year_country_temperature'
year_country_temperature = spark.sql(query)
year_country_temperature.createOrReplaceTempView("year_country_temperature")

# Display first 10 records from the newly created temp view
spark.sql("SELECT * FROM year_country_temperature LIMIT 10").toPandas()
# Out:
#    year country  min_air_temperature  max_air_temperature  avg_air_temperature
# 0  2003      NL                -14.3                 36.0            10.847775
# 1  2003      US                -44.0                 41.0             6.856936
# 2  2003      BE                -11.3                 36.3            10.945630
# 3  2003      AU                -17.6                 37.4            10.012979
# 4  2003      EZ                -16.0                 37.0             8.918003
# 5  2003      IC                 -9.0                 20.0             7.012094
# 6  2003      LU                -13.0                 37.4            10.490859
# 7  2003      GM                -15.3                 36.0             8.984825
# 8  2003      PO                 -2.0                 39.0            15.615641
# 9  2003      UK                 -7.2                 37.4            11.073555

# %% [markdown]
# ## 2.4 Aggregate Wind
#
# As the next step, create a similar query for calculating the min, max and average wind speed per country and year.

# %%
query = """
    SELECT
        year,
        country,
        min(wind_speed) AS min_wind_speed,
        max(wind_speed) AS max_wind_speed,
        avg(wind_speed) AS avg_wind_speed
    FROM joined_weather
    WHERE wind_speed_qual = '1'
    GROUP BY year,country
"""

# Create a Spark DataFrame for the SQL query above and register it as a temp view called 'year_country_wind'
year_country_wind = spark.sql(query)
year_country_wind.createOrReplaceTempView("year_country_wind")

# Display first 10 records from the newly created temp view
spark.sql("SELECT * FROM year_country_wind LIMIT 10").toPandas()
# Out:
#    year country  min_wind_speed  max_wind_speed  avg_wind_speed
# 0  2003      NL             0.0            33.4       40.490046
# 1  2003      US             0.0            35.0       68.044499
# 2  2003      BE             0.0            19.0       20.184212
# 3  2003      AU             0.0            22.6       34.653486
# 4  2003      EZ             0.0            16.5       16.807488
# 5  2003      IC             0.0            30.9       14.995883
# 6  2003      LU             0.0            16.5       27.939163
# 7  2003      GM             0.0            16.5       16.381248
# 8  2003      PO             0.0            20.0       24.131470
# 9  2003      UK             0.0            22.0       11.622068

# %% [markdown]
# ## 2.5 Join Final Result
#
# So far, we have created the two temp views `year_country_temperature` and `year_country_wind`. Both contain some aggregated attributes per country and year. Now join together both data frames using the columns `country` and `year`. Here we chose an *outer join*, since both sides of the join could provide some relevant information without the other side. The final result should contain the following columns
#
# * `year`
# * `country`
# * `min_wind_speed`
# * `max_wind_speed`
# * `avg_wind_speed`
# * `min_air_temperature`
# * `max_air_temperature`
# * `avg_air_temperature`
#
# The function SQL function `COALESCE` can be used to merge the columns `year` and `country` from the left and right sides of the joint into two final columns `year` and `country`.

# %%
query = """
    SELECT
        COALESCE(wind.year, temp.year) AS year,
        COALESCE(wind.country, temp.country) AS country,
        wind.min_wind_speed,
        wind.max_wind_speed,
        wind.avg_wind_speed,
        temp.min_air_temperature,
        temp.max_air_temperature,
        temp.avg_air_temperature
    FROM year_country_wind wind
    FULL OUTER JOIN year_country_temperature temp ON wind.year = temp.year AND wind.country = temp.country
"""

# Execute the query
result = spark.sql(query)
# Convert the result to a Pandas dataframe - this time without a 'limit' 
result.toPandas()
# Out:
#      year country  min_wind_speed  max_wind_speed  avg_wind_speed
# 0    2003      AS             0.0            14.4       24.965552  \
# 1    2003      AU             0.0            22.6       34.653486
# 2    2003      BE             0.0            19.0       20.184212
# 3    2003      CA             0.0            27.8      118.253679
# 4    2003      DA             0.0            23.0       15.369517
# ..    ...     ...             ...             ...             ...
# 480  2019      SF             0.0            10.8       37.555696
# 481  2019      SV             0.0            32.0       -4.371690
# 482  2019      SW             0.0            20.0        4.055555
# 483  2019      UK             0.0            17.0       11.209918
# 484  2019      US             0.0            25.2       14.394539
#
#      min_air_temperature  max_air_temperature  avg_air_temperature
# 0                    0.3                 45.8            23.025439
# 1                  -17.6                 37.4            10.012979
# 2                  -11.3                 36.3            10.945630
# 3                  -40.1                 35.8             1.453475
# 4                  -16.0                 30.0             8.552005
# ..                   ...                  ...                  ...
# 480                  2.7                 42.5            20.635556
# 481                -36.2                 16.0            -4.632360
# 482                -39.3                 29.3             2.710664
# 483                 -7.2                 35.0            11.100897
# 484                -47.8                 41.7            10.417694
#
# [485 rows x 8 columns]

# %% [markdown]
# # 3.0 SQL Subqueries
#
# When trying to combine all logic into a single query, you can increase readability by using a SQL subquery. Actually, subqueries can be used in various places. We will look at different examples.

# %% [markdown]
# ## 3.1 Subqueries in `FROM` clauses
#
# In our first example, we use a subquery inside the `FROM` clause. The pattern looks as follows:
#
# ```sql
#     SELECT
#         ...
#     FROM (
#         -- subquery
#         SELECT
#             ...
#     ) AS my_alias
# ```

# %%
query = """
SELECT
    year,
    CTRY AS country,
    min(air_temperature) AS min_air_temperature,
    max(air_temperature) AS max_air_temperature,
    avg(air_temperature) AS avg_air_temperature
FROM (
    -- Extract measurements
    SELECT
        year,
        substring(value,5,6) AS usaf,
        substring(value,11,5) AS wban,
        substring(value,16,8) AS `date`,
        substring(value,24,4) AS `time`,
        substring(value,42,5) AS report_type,
        substring(value,61,3) AS wind_direction,
        substring(value,64,1) AS wind_direction_qual,
        substring(value,65,1) AS wind_observation,
        CAST(substring(value,66,4) AS FLOAT) / 10.0 AS wind_speed,
        substring(value,70,1) AS wind_speed_qual,
        CAST(substring(value,88,5) AS FLOAT) / 10.0 AS air_temperature,
        substring(value,93,1) AS air_temperature_qual
    FROM raw_weather
) AS weather
-- Join measurements and master data
LEFT JOIN stations ON weather.usaf = stations.usaf AND weather.wban = stations.wban
-- Only keep valid temperature
WHERE air_temperature_qual = '1'
-- Perform grouping
GROUP BY year,CTRY
"""

# Execute the query and display result
result = spark.sql(query)
result.toPandas()
# Out:
#      year country  min_air_temperature  max_air_temperature
# 0    2003      NL                -14.3                 36.0  \
# 1    2003      US                -44.0                 41.0
# 2    2003      BE                -11.3                 36.3
# 3    2003      AU                -17.6                 37.4
# 4    2003      EZ                -16.0                 37.0
# ..    ...     ...                  ...                  ...
# 478  2019      CH                 13.0                 35.0
# 479  2019      AS                  2.7                 45.8
# 480  2019      SF                  2.7                 42.5
# 481  2019      RS                -25.9                 29.9
# 482  2019      IT                 10.0                 12.5
#
#      avg_air_temperature
# 0              10.847775
# 1               6.856936
# 2              10.945630
# 3              10.012979
# 4               8.918003
# ..                   ...
# 478            27.250057
# 479            23.224927
# 480            20.635556
# 481             4.778747
# 482            10.950000
#
# [483 rows x 5 columns]

# %% [markdown]
# ## 3.2 Scalar Subqueries
#
# SQL also supports so callaed *scalar subqueries*, which return a single value. For example, if we wanted to add a column containing the overall average temperature, this could be done as followed (using the `joined_weather` view for simplifying the query).

# %%
query = """
    SELECT
        year,
        country,
        min(air_temperature) AS min_air_temperature,
        max(air_temperature) AS max_air_temperature,
        avg(air_temperature) AS avg_air_temperature,
        (SELECT avg(air_temperature) FROM joined_weather WHERE air_temperature_qual = '1') AS overall_avg_air_temperature
    FROM joined_weather
    WHERE air_temperature_qual = '1'
    GROUP BY year,country
"""

# Execute the query and display result
result = spark.sql(query)
result.toPandas()
# Out:
#      year country  min_air_temperature  max_air_temperature
# 0    2003      NL                -14.3                 36.0  \
# 1    2003      US                -44.0                 41.0
# 2    2003      BE                -11.3                 36.3
# 3    2003      AU                -17.6                 37.4
# 4    2003      EZ                -16.0                 37.0
# ..    ...     ...                  ...                  ...
# 478  2019      CH                 13.0                 35.0
# 479  2019      AS                  2.7                 45.8
# 480  2019      SF                  2.7                 42.5
# 481  2019      RS                -25.9                 29.9
# 482  2019      IT                 10.0                 12.5
#
#      avg_air_temperature  overall_avg_air_temperature
# 0              10.847775                     9.034332
# 1               6.856936                     9.034332
# 2              10.945630                     9.034332
# 3              10.012979                     9.034332
# 4               8.918003                     9.034332
# ..                   ...                          ...
# 478            27.250057                     9.034332
# 479            23.224927                     9.034332
# 480            20.635556                     9.034332
# 481             4.778747                     9.034332
# 482            10.950000                     9.034332
#
# [483 rows x 6 columns]

# %% [markdown]
# ### Execution Plan
#
# Let's inspect the execution plan, which should also include the subquery as a separate stage/job.

# %%
result.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=true
# +- == Final Plan ==
#    *(20) HashAggregate(keys=[year#2, country#461], functions=[min(air_temperature#224), max(air_temperature#224), avg(air_temperature#224)])
#    :  +- Subquery subquery#2024, [id=#4336]
#    :     +- AdaptiveSparkPlan isFinalPlan=true
#          +- == Final Plan ==
#             *(20) HashAggregate(keys=[], functions=[avg(air_temperature#224)])
#             +- ShuffleQueryStage 1
#                +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=5079]
#                   +- *(19) HashAggregate(keys=[], functions=[partial_avg(air_temperature#224)])
#                      +- *(19) Project [air_temperature#224]
#                         +- *(19) BroadcastHashJoin [usaf#214, wban#215], [usaf#2048, wban#2049], LeftOuter, BuildRight, false
#                            :- Union
#                            :  :- *(2) Project [substring(value#2031, 5, 6) AS usaf#214, substring(value#2031, 11, 5) AS wban#215, (cast(cast(substring(value#2031, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                            :  :  +- *(2) Filter (isnotnull(value#2031) AND (substring(value#2031, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2031] Batched: false, DataFilters: [isnotnull(value#2031), (substring(value#2031, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(3) Project [substring(value#2032, 5, 6) AS usaf#2065, substring(value#2032, 11, 5) AS wban#2066, (cast(cast(substring(value#2032, 88, 5) as float) as double) / 10.0) AS air_temperature#2075]
#                            :  :  +- *(3) Filter (isnotnull(value#2032) AND (substring(value#2032, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2032] Batched: false, DataFilters: [isnotnull(value#2032), (substring(value#2032, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(4) Project [substring(value#2033, 5, 6) AS usaf#2077, substring(value#2033, 11, 5) AS wban#2078, (cast(cast(substring(value#2033, 88, 5) as float) as double) / 10.0) AS air_temperature#2087]
#                            :  :  +- *(4) Filter (isnotnull(value#2033) AND (substring(value#2033, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2033] Batched: false, DataFilters: [isnotnull(value#2033), (substring(value#2033, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(5) Project [substring(value#2034, 5, 6) AS usaf#2089, substring(value#2034, 11, 5) AS wban#2090, (cast(cast(substring(value#2034, 88, 5) as float) as double) / 10.0) AS air_temperature#2099]
#                            :  :  +- *(5) Filter (isnotnull(value#2034) AND (substring(value#2034, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2034] Batched: false, DataFilters: [isnotnull(value#2034), (substring(value#2034, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(6) Project [substring(value#2035, 5, 6) AS usaf#2101, substring(value#2035, 11, 5) AS wban#2102, (cast(cast(substring(value#2035, 88, 5) as float) as double) / 10.0) AS air_temperature#2111]
#                            :  :  +- *(6) Filter (isnotnull(value#2035) AND (substring(value#2035, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2035] Batched: false, DataFilters: [isnotnull(value#2035), (substring(value#2035, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(7) Project [substring(value#2036, 5, 6) AS usaf#2113, substring(value#2036, 11, 5) AS wban#2114, (cast(cast(substring(value#2036, 88, 5) as float) as double) / 10.0) AS air_temperature#2123]
#                            :  :  +- *(7) Filter (isnotnull(value#2036) AND (substring(value#2036, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2036] Batched: false, DataFilters: [isnotnull(value#2036), (substring(value#2036, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(8) Project [substring(value#2037, 5, 6) AS usaf#2125, substring(value#2037, 11, 5) AS wban#2126, (cast(cast(substring(value#2037, 88, 5) as float) as double) / 10.0) AS air_temperature#2135]
#                            :  :  +- *(8) Filter (isnotnull(value#2037) AND (substring(value#2037, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2037] Batched: false, DataFilters: [isnotnull(value#2037), (substring(value#2037, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(9) Project [substring(value#2038, 5, 6) AS usaf#2137, substring(value#2038, 11, 5) AS wban#2138, (cast(cast(substring(value#2038, 88, 5) as float) as double) / 10.0) AS air_temperature#2147]
#                            :  :  +- *(9) Filter (isnotnull(value#2038) AND (substring(value#2038, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2038] Batched: false, DataFilters: [isnotnull(value#2038), (substring(value#2038, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(10) Project [substring(value#2039, 5, 6) AS usaf#2149, substring(value#2039, 11, 5) AS wban#2150, (cast(cast(substring(value#2039, 88, 5) as float) as double) / 10.0) AS air_temperature#2159]
#                            :  :  +- *(10) Filter (isnotnull(value#2039) AND (substring(value#2039, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2039] Batched: false, DataFilters: [isnotnull(value#2039), (substring(value#2039, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(11) Project [substring(value#2040, 5, 6) AS usaf#2161, substring(value#2040, 11, 5) AS wban#2162, (cast(cast(substring(value#2040, 88, 5) as float) as double) / 10.0) AS air_temperature#2171]
#                            :  :  +- *(11) Filter (isnotnull(value#2040) AND (substring(value#2040, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2040] Batched: false, DataFilters: [isnotnull(value#2040), (substring(value#2040, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(12) Project [substring(value#2041, 5, 6) AS usaf#2173, substring(value#2041, 11, 5) AS wban#2174, (cast(cast(substring(value#2041, 88, 5) as float) as double) / 10.0) AS air_temperature#2183]
#                            :  :  +- *(12) Filter (isnotnull(value#2041) AND (substring(value#2041, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2041] Batched: false, DataFilters: [isnotnull(value#2041), (substring(value#2041, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(13) Project [substring(value#2042, 5, 6) AS usaf#2185, substring(value#2042, 11, 5) AS wban#2186, (cast(cast(substring(value#2042, 88, 5) as float) as double) / 10.0) AS air_temperature#2195]
#                            :  :  +- *(13) Filter (isnotnull(value#2042) AND (substring(value#2042, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2042] Batched: false, DataFilters: [isnotnull(value#2042), (substring(value#2042, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(14) Project [substring(value#2043, 5, 6) AS usaf#2197, substring(value#2043, 11, 5) AS wban#2198, (cast(cast(substring(value#2043, 88, 5) as float) as double) / 10.0) AS air_temperature#2207]
#                            :  :  +- *(14) Filter (isnotnull(value#2043) AND (substring(value#2043, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2043] Batched: false, DataFilters: [isnotnull(value#2043), (substring(value#2043, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(15) Project [substring(value#2044, 5, 6) AS usaf#2209, substring(value#2044, 11, 5) AS wban#2210, (cast(cast(substring(value#2044, 88, 5) as float) as double) / 10.0) AS air_temperature#2219]
#                            :  :  +- *(15) Filter (isnotnull(value#2044) AND (substring(value#2044, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2044] Batched: false, DataFilters: [isnotnull(value#2044), (substring(value#2044, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(16) Project [substring(value#2045, 5, 6) AS usaf#2221, substring(value#2045, 11, 5) AS wban#2222, (cast(cast(substring(value#2045, 88, 5) as float) as double) / 10.0) AS air_temperature#2231]
#                            :  :  +- *(16) Filter (isnotnull(value#2045) AND (substring(value#2045, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2045] Batched: false, DataFilters: [isnotnull(value#2045), (substring(value#2045, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(17) Project [substring(value#2046, 5, 6) AS usaf#2233, substring(value#2046, 11, 5) AS wban#2234, (cast(cast(substring(value#2046, 88, 5) as float) as double) / 10.0) AS air_temperature#2243]
#                            :  :  +- *(17) Filter (isnotnull(value#2046) AND (substring(value#2046, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2046] Batched: false, DataFilters: [isnotnull(value#2046), (substring(value#2046, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  +- *(18) Project [substring(value#2047, 5, 6) AS usaf#2245, substring(value#2047, 11, 5) AS wban#2246, (cast(cast(substring(value#2047, 88, 5) as float) as double) / 10.0) AS air_temperature#2255]
#                            :     +- *(18) Filter (isnotnull(value#2047) AND (substring(value#2047, 93, 1) = 1))
#                            :        +- FileScan text [value#2047] Batched: false, DataFilters: [isnotnull(value#2047), (substring(value#2047, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            +- BroadcastQueryStage 0
#                               +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=4883]
#                                  +- *(1) Filter (isnotnull(usaf#2048) AND isnotnull(wban#2049))
#                                     +- FileScan csv [USAF#2048,WBAN#2049] Batched: false, DataFilters: [isnotnull(USAF#2048), isnotnull(WBAN#2049)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string>
#          +- == Initial Plan ==
#             HashAggregate(keys=[], functions=[avg(air_temperature#224)])
#             +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=4334]
#                +- HashAggregate(keys=[], functions=[partial_avg(air_temperature#224)])
#                   +- Project [air_temperature#224]
#                      +- BroadcastHashJoin [usaf#214, wban#215], [usaf#2048, wban#2049], LeftOuter, BuildRight, false
#                         :- Union
#                         :  :- Project [substring(value#2031, 5, 6) AS usaf#214, substring(value#2031, 11, 5) AS wban#215, (cast(cast(substring(value#2031, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                         :  :  +- Filter (isnotnull(value#2031) AND (substring(value#2031, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2031] Batched: false, DataFilters: [isnotnull(value#2031), (substring(value#2031, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2032, 5, 6) AS usaf#2065, substring(value#2032, 11, 5) AS wban#2066, (cast(cast(substring(value#2032, 88, 5) as float) as double) / 10.0) AS air_temperature#2075]
#                         :  :  +- Filter (isnotnull(value#2032) AND (substring(value#2032, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2032] Batched: false, DataFilters: [isnotnull(value#2032), (substring(value#2032, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2033, 5, 6) AS usaf#2077, substring(value#2033, 11, 5) AS wban#2078, (cast(cast(substring(value#2033, 88, 5) as float) as double) / 10.0) AS air_temperature#2087]
#                         :  :  +- Filter (isnotnull(value#2033) AND (substring(value#2033, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2033] Batched: false, DataFilters: [isnotnull(value#2033), (substring(value#2033, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2034, 5, 6) AS usaf#2089, substring(value#2034, 11, 5) AS wban#2090, (cast(cast(substring(value#2034, 88, 5) as float) as double) / 10.0) AS air_temperature#2099]
#                         :  :  +- Filter (isnotnull(value#2034) AND (substring(value#2034, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2034] Batched: false, DataFilters: [isnotnull(value#2034), (substring(value#2034, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2035, 5, 6) AS usaf#2101, substring(value#2035, 11, 5) AS wban#2102, (cast(cast(substring(value#2035, 88, 5) as float) as double) / 10.0) AS air_temperature#2111]
#                         :  :  +- Filter (isnotnull(value#2035) AND (substring(value#2035, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2035] Batched: false, DataFilters: [isnotnull(value#2035), (substring(value#2035, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2036, 5, 6) AS usaf#2113, substring(value#2036, 11, 5) AS wban#2114, (cast(cast(substring(value#2036, 88, 5) as float) as double) / 10.0) AS air_temperature#2123]
#                         :  :  +- Filter (isnotnull(value#2036) AND (substring(value#2036, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2036] Batched: false, DataFilters: [isnotnull(value#2036), (substring(value#2036, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2037, 5, 6) AS usaf#2125, substring(value#2037, 11, 5) AS wban#2126, (cast(cast(substring(value#2037, 88, 5) as float) as double) / 10.0) AS air_temperature#2135]
#                         :  :  +- Filter (isnotnull(value#2037) AND (substring(value#2037, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2037] Batched: false, DataFilters: [isnotnull(value#2037), (substring(value#2037, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2038, 5, 6) AS usaf#2137, substring(value#2038, 11, 5) AS wban#2138, (cast(cast(substring(value#2038, 88, 5) as float) as double) / 10.0) AS air_temperature#2147]
#                         :  :  +- Filter (isnotnull(value#2038) AND (substring(value#2038, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2038] Batched: false, DataFilters: [isnotnull(value#2038), (substring(value#2038, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2039, 5, 6) AS usaf#2149, substring(value#2039, 11, 5) AS wban#2150, (cast(cast(substring(value#2039, 88, 5) as float) as double) / 10.0) AS air_temperature#2159]
#                         :  :  +- Filter (isnotnull(value#2039) AND (substring(value#2039, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2039] Batched: false, DataFilters: [isnotnull(value#2039), (substring(value#2039, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2040, 5, 6) AS usaf#2161, substring(value#2040, 11, 5) AS wban#2162, (cast(cast(substring(value#2040, 88, 5) as float) as double) / 10.0) AS air_temperature#2171]
#                         :  :  +- Filter (isnotnull(value#2040) AND (substring(value#2040, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2040] Batched: false, DataFilters: [isnotnull(value#2040), (substring(value#2040, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2041, 5, 6) AS usaf#2173, substring(value#2041, 11, 5) AS wban#2174, (cast(cast(substring(value#2041, 88, 5) as float) as double) / 10.0) AS air_temperature#2183]
#                         :  :  +- Filter (isnotnull(value#2041) AND (substring(value#2041, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2041] Batched: false, DataFilters: [isnotnull(value#2041), (substring(value#2041, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2042, 5, 6) AS usaf#2185, substring(value#2042, 11, 5) AS wban#2186, (cast(cast(substring(value#2042, 88, 5) as float) as double) / 10.0) AS air_temperature#2195]
#                         :  :  +- Filter (isnotnull(value#2042) AND (substring(value#2042, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2042] Batched: false, DataFilters: [isnotnull(value#2042), (substring(value#2042, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2043, 5, 6) AS usaf#2197, substring(value#2043, 11, 5) AS wban#2198, (cast(cast(substring(value#2043, 88, 5) as float) as double) / 10.0) AS air_temperature#2207]
#                         :  :  +- Filter (isnotnull(value#2043) AND (substring(value#2043, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2043] Batched: false, DataFilters: [isnotnull(value#2043), (substring(value#2043, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2044, 5, 6) AS usaf#2209, substring(value#2044, 11, 5) AS wban#2210, (cast(cast(substring(value#2044, 88, 5) as float) as double) / 10.0) AS air_temperature#2219]
#                         :  :  +- Filter (isnotnull(value#2044) AND (substring(value#2044, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2044] Batched: false, DataFilters: [isnotnull(value#2044), (substring(value#2044, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2045, 5, 6) AS usaf#2221, substring(value#2045, 11, 5) AS wban#2222, (cast(cast(substring(value#2045, 88, 5) as float) as double) / 10.0) AS air_temperature#2231]
#                         :  :  +- Filter (isnotnull(value#2045) AND (substring(value#2045, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2045] Batched: false, DataFilters: [isnotnull(value#2045), (substring(value#2045, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2046, 5, 6) AS usaf#2233, substring(value#2046, 11, 5) AS wban#2234, (cast(cast(substring(value#2046, 88, 5) as float) as double) / 10.0) AS air_temperature#2243]
#                         :  :  +- Filter (isnotnull(value#2046) AND (substring(value#2046, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2046] Batched: false, DataFilters: [isnotnull(value#2046), (substring(value#2046, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  +- Project [substring(value#2047, 5, 6) AS usaf#2245, substring(value#2047, 11, 5) AS wban#2246, (cast(cast(substring(value#2047, 88, 5) as float) as double) / 10.0) AS air_temperature#2255]
#                         :     +- Filter (isnotnull(value#2047) AND (substring(value#2047, 93, 1) = 1))
#                         :        +- FileScan text [value#2047] Batched: false, DataFilters: [isnotnull(value#2047), (substring(value#2047, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=4329]
#                            +- Filter (isnotnull(usaf#2048) AND isnotnull(wban#2049))
#                               +- FileScan csv [USAF#2048,WBAN#2049] Batched: false, DataFilters: [isnotnull(USAF#2048), isnotnull(WBAN#2049)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string>
#    +- AQEShuffleRead coalesced
#       +- ShuffleQueryStage 1
#          +- Exchange hashpartitioning(year#2, country#461, 200), ENSURE_REQUIREMENTS, [plan_id=4749]
#             +- *(19) HashAggregate(keys=[year#2, country#461], functions=[partial_min(air_temperature#224), partial_max(air_temperature#224), partial_avg(air_temperature#224)])
#                +- *(19) Project [year#2, air_temperature#224, CTRY#173 AS country#461]
#                   +- *(19) BroadcastHashJoin [usaf#214, wban#215], [usaf#170, wban#171], LeftOuter, BuildRight, false
#                      :- Union
#                      :  :- *(2) Project [2003 AS year#2, substring(value#0, 5, 6) AS usaf#214, substring(value#0, 11, 5) AS wban#215, (cast(cast(substring(value#0, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                      :  :  +- *(2) Filter (isnotnull(value#0) AND (substring(value#0, 93, 1) = 1))
#                      :  :     +- FileScan text [value#0] Batched: false, DataFilters: [isnotnull(value#0), (substring(value#0, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(3) Project [2004 AS year#8, substring(value#6, 5, 6) AS usaf#2257, substring(value#6, 11, 5) AS wban#2258, (cast(cast(substring(value#6, 88, 5) as float) as double) / 10.0) AS air_temperature#2267]
#                      :  :  +- *(3) Filter (isnotnull(value#6) AND (substring(value#6, 93, 1) = 1))
#                      :  :     +- FileScan text [value#6] Batched: false, DataFilters: [isnotnull(value#6), (substring(value#6, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(4) Project [2005 AS year#14, substring(value#12, 5, 6) AS usaf#2269, substring(value#12, 11, 5) AS wban#2270, (cast(cast(substring(value#12, 88, 5) as float) as double) / 10.0) AS air_temperature#2279]
#                      :  :  +- *(4) Filter (isnotnull(value#12) AND (substring(value#12, 93, 1) = 1))
#                      :  :     +- FileScan text [value#12] Batched: false, DataFilters: [isnotnull(value#12), (substring(value#12, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(5) Project [2006 AS year#20, substring(value#18, 5, 6) AS usaf#2281, substring(value#18, 11, 5) AS wban#2282, (cast(cast(substring(value#18, 88, 5) as float) as double) / 10.0) AS air_temperature#2291]
#                      :  :  +- *(5) Filter (isnotnull(value#18) AND (substring(value#18, 93, 1) = 1))
#                      :  :     +- FileScan text [value#18] Batched: false, DataFilters: [isnotnull(value#18), (substring(value#18, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(6) Project [2007 AS year#26, substring(value#24, 5, 6) AS usaf#2293, substring(value#24, 11, 5) AS wban#2294, (cast(cast(substring(value#24, 88, 5) as float) as double) / 10.0) AS air_temperature#2303]
#                      :  :  +- *(6) Filter (isnotnull(value#24) AND (substring(value#24, 93, 1) = 1))
#                      :  :     +- FileScan text [value#24] Batched: false, DataFilters: [isnotnull(value#24), (substring(value#24, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(7) Project [2008 AS year#32, substring(value#30, 5, 6) AS usaf#2305, substring(value#30, 11, 5) AS wban#2306, (cast(cast(substring(value#30, 88, 5) as float) as double) / 10.0) AS air_temperature#2315]
#                      :  :  +- *(7) Filter (isnotnull(value#30) AND (substring(value#30, 93, 1) = 1))
#                      :  :     +- FileScan text [value#30] Batched: false, DataFilters: [isnotnull(value#30), (substring(value#30, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(8) Project [2009 AS year#38, substring(value#36, 5, 6) AS usaf#2317, substring(value#36, 11, 5) AS wban#2318, (cast(cast(substring(value#36, 88, 5) as float) as double) / 10.0) AS air_temperature#2327]
#                      :  :  +- *(8) Filter (isnotnull(value#36) AND (substring(value#36, 93, 1) = 1))
#                      :  :     +- FileScan text [value#36] Batched: false, DataFilters: [isnotnull(value#36), (substring(value#36, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(9) Project [2010 AS year#44, substring(value#42, 5, 6) AS usaf#2329, substring(value#42, 11, 5) AS wban#2330, (cast(cast(substring(value#42, 88, 5) as float) as double) / 10.0) AS air_temperature#2339]
#                      :  :  +- *(9) Filter (isnotnull(value#42) AND (substring(value#42, 93, 1) = 1))
#                      :  :     +- FileScan text [value#42] Batched: false, DataFilters: [isnotnull(value#42), (substring(value#42, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(10) Project [2011 AS year#50, substring(value#48, 5, 6) AS usaf#2341, substring(value#48, 11, 5) AS wban#2342, (cast(cast(substring(value#48, 88, 5) as float) as double) / 10.0) AS air_temperature#2351]
#                      :  :  +- *(10) Filter (isnotnull(value#48) AND (substring(value#48, 93, 1) = 1))
#                      :  :     +- FileScan text [value#48] Batched: false, DataFilters: [isnotnull(value#48), (substring(value#48, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(11) Project [2012 AS year#56, substring(value#54, 5, 6) AS usaf#2353, substring(value#54, 11, 5) AS wban#2354, (cast(cast(substring(value#54, 88, 5) as float) as double) / 10.0) AS air_temperature#2363]
#                      :  :  +- *(11) Filter (isnotnull(value#54) AND (substring(value#54, 93, 1) = 1))
#                      :  :     +- FileScan text [value#54] Batched: false, DataFilters: [isnotnull(value#54), (substring(value#54, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(12) Project [2013 AS year#62, substring(value#60, 5, 6) AS usaf#2365, substring(value#60, 11, 5) AS wban#2366, (cast(cast(substring(value#60, 88, 5) as float) as double) / 10.0) AS air_temperature#2375]
#                      :  :  +- *(12) Filter (isnotnull(value#60) AND (substring(value#60, 93, 1) = 1))
#                      :  :     +- FileScan text [value#60] Batched: false, DataFilters: [isnotnull(value#60), (substring(value#60, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(13) Project [2014 AS year#68, substring(value#66, 5, 6) AS usaf#2377, substring(value#66, 11, 5) AS wban#2378, (cast(cast(substring(value#66, 88, 5) as float) as double) / 10.0) AS air_temperature#2387]
#                      :  :  +- *(13) Filter (isnotnull(value#66) AND (substring(value#66, 93, 1) = 1))
#                      :  :     +- FileScan text [value#66] Batched: false, DataFilters: [isnotnull(value#66), (substring(value#66, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(14) Project [2015 AS year#74, substring(value#72, 5, 6) AS usaf#2389, substring(value#72, 11, 5) AS wban#2390, (cast(cast(substring(value#72, 88, 5) as float) as double) / 10.0) AS air_temperature#2399]
#                      :  :  +- *(14) Filter (isnotnull(value#72) AND (substring(value#72, 93, 1) = 1))
#                      :  :     +- FileScan text [value#72] Batched: false, DataFilters: [isnotnull(value#72), (substring(value#72, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(15) Project [2016 AS year#80, substring(value#78, 5, 6) AS usaf#2401, substring(value#78, 11, 5) AS wban#2402, (cast(cast(substring(value#78, 88, 5) as float) as double) / 10.0) AS air_temperature#2411]
#                      :  :  +- *(15) Filter (isnotnull(value#78) AND (substring(value#78, 93, 1) = 1))
#                      :  :     +- FileScan text [value#78] Batched: false, DataFilters: [isnotnull(value#78), (substring(value#78, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(16) Project [2017 AS year#86, substring(value#84, 5, 6) AS usaf#2413, substring(value#84, 11, 5) AS wban#2414, (cast(cast(substring(value#84, 88, 5) as float) as double) / 10.0) AS air_temperature#2423]
#                      :  :  +- *(16) Filter (isnotnull(value#84) AND (substring(value#84, 93, 1) = 1))
#                      :  :     +- FileScan text [value#84] Batched: false, DataFilters: [isnotnull(value#84), (substring(value#84, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  :- *(17) Project [2018 AS year#92, substring(value#90, 5, 6) AS usaf#2425, substring(value#90, 11, 5) AS wban#2426, (cast(cast(substring(value#90, 88, 5) as float) as double) / 10.0) AS air_temperature#2435]
#                      :  :  +- *(17) Filter (isnotnull(value#90) AND (substring(value#90, 93, 1) = 1))
#                      :  :     +- FileScan text [value#90] Batched: false, DataFilters: [isnotnull(value#90), (substring(value#90, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      :  +- *(18) Project [2019 AS year#98, substring(value#96, 5, 6) AS usaf#2437, substring(value#96, 11, 5) AS wban#2438, (cast(cast(substring(value#96, 88, 5) as float) as double) / 10.0) AS air_temperature#2447]
#                      :     +- *(18) Filter (isnotnull(value#96) AND (substring(value#96, 93, 1) = 1))
#                      :        +- FileScan text [value#96] Batched: false, DataFilters: [isnotnull(value#96), (substring(value#96, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                      +- BroadcastQueryStage 0
#                         +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=4551]
#                            +- *(1) Filter (isnotnull(usaf#170) AND isnotnull(wban#171))
#                               +- FileScan csv [USAF#170,WBAN#171,CTRY#173] Batched: false, DataFilters: [isnotnull(USAF#170), isnotnull(WBAN#171)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string,CTRY:string>
# +- == Initial Plan ==
#    HashAggregate(keys=[year#2, country#461], functions=[min(air_temperature#224), max(air_temperature#224), avg(air_temperature#224)])
#    :  +- Subquery subquery#2024, [id=#4336]
#    :     +- AdaptiveSparkPlan isFinalPlan=true
#          +- == Final Plan ==
#             *(20) HashAggregate(keys=[], functions=[avg(air_temperature#224)])
#             +- ShuffleQueryStage 1
#                +- Exchange SinglePartition, ENSURE_REQUIREMENTS, [plan_id=5079]
#                   +- *(19) HashAggregate(keys=[], functions=[partial_avg(air_temperature#224)])
#                      +- *(19) Project [air_temperature#224]
#                         +- *(19) BroadcastHashJoin [usaf#214, wban#215], [usaf#2048, wban#2049], LeftOuter, BuildRight, false
#                            :- Union
#                            :  :- *(2) Project [substring(value#2031, 5, 6) AS usaf#214, substring(value#2031, 11, 5) AS wban#215, (cast(cast(substring(value#2031, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                            :  :  +- *(2) Filter (isnotnull(value#2031) AND (substring(value#2031, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2031] Batched: false, DataFilters: [isnotnull(value#2031), (substring(value#2031, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(3) Project [substring(value#2032, 5, 6) AS usaf#2065, substring(value#2032, 11, 5) AS wban#2066, (cast(cast(substring(value#2032, 88, 5) as float) as double) / 10.0) AS air_temperature#2075]
#                            :  :  +- *(3) Filter (isnotnull(value#2032) AND (substring(value#2032, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2032] Batched: false, DataFilters: [isnotnull(value#2032), (substring(value#2032, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(4) Project [substring(value#2033, 5, 6) AS usaf#2077, substring(value#2033, 11, 5) AS wban#2078, (cast(cast(substring(value#2033, 88, 5) as float) as double) / 10.0) AS air_temperature#2087]
#                            :  :  +- *(4) Filter (isnotnull(value#2033) AND (substring(value#2033, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2033] Batched: false, DataFilters: [isnotnull(value#2033), (substring(value#2033, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(5) Project [substring(value#2034, 5, 6) AS usaf#2089, substring(value#2034, 11, 5) AS wban#2090, (cast(cast(substring(value#2034, 88, 5) as float) as double) / 10.0) AS air_temperature#2099]
#                            :  :  +- *(5) Filter (isnotnull(value#2034) AND (substring(value#2034, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2034] Batched: false, DataFilters: [isnotnull(value#2034), (substring(value#2034, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(6) Project [substring(value#2035, 5, 6) AS usaf#2101, substring(value#2035, 11, 5) AS wban#2102, (cast(cast(substring(value#2035, 88, 5) as float) as double) / 10.0) AS air_temperature#2111]
#                            :  :  +- *(6) Filter (isnotnull(value#2035) AND (substring(value#2035, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2035] Batched: false, DataFilters: [isnotnull(value#2035), (substring(value#2035, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(7) Project [substring(value#2036, 5, 6) AS usaf#2113, substring(value#2036, 11, 5) AS wban#2114, (cast(cast(substring(value#2036, 88, 5) as float) as double) / 10.0) AS air_temperature#2123]
#                            :  :  +- *(7) Filter (isnotnull(value#2036) AND (substring(value#2036, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2036] Batched: false, DataFilters: [isnotnull(value#2036), (substring(value#2036, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(8) Project [substring(value#2037, 5, 6) AS usaf#2125, substring(value#2037, 11, 5) AS wban#2126, (cast(cast(substring(value#2037, 88, 5) as float) as double) / 10.0) AS air_temperature#2135]
#                            :  :  +- *(8) Filter (isnotnull(value#2037) AND (substring(value#2037, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2037] Batched: false, DataFilters: [isnotnull(value#2037), (substring(value#2037, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(9) Project [substring(value#2038, 5, 6) AS usaf#2137, substring(value#2038, 11, 5) AS wban#2138, (cast(cast(substring(value#2038, 88, 5) as float) as double) / 10.0) AS air_temperature#2147]
#                            :  :  +- *(9) Filter (isnotnull(value#2038) AND (substring(value#2038, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2038] Batched: false, DataFilters: [isnotnull(value#2038), (substring(value#2038, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(10) Project [substring(value#2039, 5, 6) AS usaf#2149, substring(value#2039, 11, 5) AS wban#2150, (cast(cast(substring(value#2039, 88, 5) as float) as double) / 10.0) AS air_temperature#2159]
#                            :  :  +- *(10) Filter (isnotnull(value#2039) AND (substring(value#2039, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2039] Batched: false, DataFilters: [isnotnull(value#2039), (substring(value#2039, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(11) Project [substring(value#2040, 5, 6) AS usaf#2161, substring(value#2040, 11, 5) AS wban#2162, (cast(cast(substring(value#2040, 88, 5) as float) as double) / 10.0) AS air_temperature#2171]
#                            :  :  +- *(11) Filter (isnotnull(value#2040) AND (substring(value#2040, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2040] Batched: false, DataFilters: [isnotnull(value#2040), (substring(value#2040, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(12) Project [substring(value#2041, 5, 6) AS usaf#2173, substring(value#2041, 11, 5) AS wban#2174, (cast(cast(substring(value#2041, 88, 5) as float) as double) / 10.0) AS air_temperature#2183]
#                            :  :  +- *(12) Filter (isnotnull(value#2041) AND (substring(value#2041, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2041] Batched: false, DataFilters: [isnotnull(value#2041), (substring(value#2041, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(13) Project [substring(value#2042, 5, 6) AS usaf#2185, substring(value#2042, 11, 5) AS wban#2186, (cast(cast(substring(value#2042, 88, 5) as float) as double) / 10.0) AS air_temperature#2195]
#                            :  :  +- *(13) Filter (isnotnull(value#2042) AND (substring(value#2042, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2042] Batched: false, DataFilters: [isnotnull(value#2042), (substring(value#2042, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(14) Project [substring(value#2043, 5, 6) AS usaf#2197, substring(value#2043, 11, 5) AS wban#2198, (cast(cast(substring(value#2043, 88, 5) as float) as double) / 10.0) AS air_temperature#2207]
#                            :  :  +- *(14) Filter (isnotnull(value#2043) AND (substring(value#2043, 93, 1) = 1))
#                            :  :     +- FileScan text [value#2043] Batched: false, DataFilters: [isnotnull(value#2043), (substring(value#2043, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                            :  :- *(15) Project [substring(value#2044, 5, 6) AS usaf#2209, substring(value#2044, 11, 5) AS wban#2210, (cast(cast(substring(value#2044, 88, 5) as float) as double) / 10.0) AS air_temperature#2219]
#                            :  :  +- *(15) Filter (isnotnull(value#2044) AND (substring(value#2044, 93, 1) = 1))
# ...
#                         :  :- Project [substring(value#2043, 5, 6) AS usaf#2197, substring(value#2043, 11, 5) AS wban#2198, (cast(cast(substring(value#2043, 88, 5) as float) as double) / 10.0) AS air_temperature#2207]
#                         :  :  +- Filter (isnotnull(value#2043) AND (substring(value#2043, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2043] Batched: false, DataFilters: [isnotnull(value#2043), (substring(value#2043, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2044, 5, 6) AS usaf#2209, substring(value#2044, 11, 5) AS wban#2210, (cast(cast(substring(value#2044, 88, 5) as float) as double) / 10.0) AS air_temperature#2219]
#                         :  :  +- Filter (isnotnull(value#2044) AND (substring(value#2044, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2044] Batched: false, DataFilters: [isnotnull(value#2044), (substring(value#2044, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2045, 5, 6) AS usaf#2221, substring(value#2045, 11, 5) AS wban#2222, (cast(cast(substring(value#2045, 88, 5) as float) as double) / 10.0) AS air_temperature#2231]
#                         :  :  +- Filter (isnotnull(value#2045) AND (substring(value#2045, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2045] Batched: false, DataFilters: [isnotnull(value#2045), (substring(value#2045, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#2046, 5, 6) AS usaf#2233, substring(value#2046, 11, 5) AS wban#2234, (cast(cast(substring(value#2046, 88, 5) as float) as double) / 10.0) AS air_temperature#2243]
#                         :  :  +- Filter (isnotnull(value#2046) AND (substring(value#2046, 93, 1) = 1))
#                         :  :     +- FileScan text [value#2046] Batched: false, DataFilters: [isnotnull(value#2046), (substring(value#2046, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  +- Project [substring(value#2047, 5, 6) AS usaf#2245, substring(value#2047, 11, 5) AS wban#2246, (cast(cast(substring(value#2047, 88, 5) as float) as double) / 10.0) AS air_temperature#2255]
#                         :     +- Filter (isnotnull(value#2047) AND (substring(value#2047, 93, 1) = 1))
#                         :        +- FileScan text [value#2047] Batched: false, DataFilters: [isnotnull(value#2047), (substring(value#2047, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=4329]
#                            +- Filter (isnotnull(usaf#2048) AND isnotnull(wban#2049))
#                               +- FileScan csv [USAF#2048,WBAN#2049] Batched: false, DataFilters: [isnotnull(USAF#2048), isnotnull(WBAN#2049)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string>
#    +- Exchange hashpartitioning(year#2, country#461, 200), ENSURE_REQUIREMENTS, [plan_id=4348]
#       +- HashAggregate(keys=[year#2, country#461], functions=[partial_min(air_temperature#224), partial_max(air_temperature#224), partial_avg(air_temperature#224)])
#          +- Project [year#2, air_temperature#224, CTRY#173 AS country#461]
#             +- BroadcastHashJoin [usaf#214, wban#215], [usaf#170, wban#171], LeftOuter, BuildRight, false
#                :- Union
#                :  :- Project [2003 AS year#2, substring(value#0, 5, 6) AS usaf#214, substring(value#0, 11, 5) AS wban#215, (cast(cast(substring(value#0, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                :  :  +- Filter (isnotnull(value#0) AND (substring(value#0, 93, 1) = 1))
#                :  :     +- FileScan text [value#0] Batched: false, DataFilters: [isnotnull(value#0), (substring(value#0, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2004 AS year#8, substring(value#6, 5, 6) AS usaf#2257, substring(value#6, 11, 5) AS wban#2258, (cast(cast(substring(value#6, 88, 5) as float) as double) / 10.0) AS air_temperature#2267]
#                :  :  +- Filter (isnotnull(value#6) AND (substring(value#6, 93, 1) = 1))
#                :  :     +- FileScan text [value#6] Batched: false, DataFilters: [isnotnull(value#6), (substring(value#6, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2005 AS year#14, substring(value#12, 5, 6) AS usaf#2269, substring(value#12, 11, 5) AS wban#2270, (cast(cast(substring(value#12, 88, 5) as float) as double) / 10.0) AS air_temperature#2279]
#                :  :  +- Filter (isnotnull(value#12) AND (substring(value#12, 93, 1) = 1))
#                :  :     +- FileScan text [value#12] Batched: false, DataFilters: [isnotnull(value#12), (substring(value#12, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2006 AS year#20, substring(value#18, 5, 6) AS usaf#2281, substring(value#18, 11, 5) AS wban#2282, (cast(cast(substring(value#18, 88, 5) as float) as double) / 10.0) AS air_temperature#2291]
#                :  :  +- Filter (isnotnull(value#18) AND (substring(value#18, 93, 1) = 1))
#                :  :     +- FileScan text [value#18] Batched: false, DataFilters: [isnotnull(value#18), (substring(value#18, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2007 AS year#26, substring(value#24, 5, 6) AS usaf#2293, substring(value#24, 11, 5) AS wban#2294, (cast(cast(substring(value#24, 88, 5) as float) as double) / 10.0) AS air_temperature#2303]
#                :  :  +- Filter (isnotnull(value#24) AND (substring(value#24, 93, 1) = 1))
#                :  :     +- FileScan text [value#24] Batched: false, DataFilters: [isnotnull(value#24), (substring(value#24, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2008 AS year#32, substring(value#30, 5, 6) AS usaf#2305, substring(value#30, 11, 5) AS wban#2306, (cast(cast(substring(value#30, 88, 5) as float) as double) / 10.0) AS air_temperature#2315]
#                :  :  +- Filter (isnotnull(value#30) AND (substring(value#30, 93, 1) = 1))
#                :  :     +- FileScan text [value#30] Batched: false, DataFilters: [isnotnull(value#30), (substring(value#30, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2009 AS year#38, substring(value#36, 5, 6) AS usaf#2317, substring(value#36, 11, 5) AS wban#2318, (cast(cast(substring(value#36, 88, 5) as float) as double) / 10.0) AS air_temperature#2327]
#                :  :  +- Filter (isnotnull(value#36) AND (substring(value#36, 93, 1) = 1))
#                :  :     +- FileScan text [value#36] Batched: false, DataFilters: [isnotnull(value#36), (substring(value#36, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2010 AS year#44, substring(value#42, 5, 6) AS usaf#2329, substring(value#42, 11, 5) AS wban#2330, (cast(cast(substring(value#42, 88, 5) as float) as double) / 10.0) AS air_temperature#2339]
#                :  :  +- Filter (isnotnull(value#42) AND (substring(value#42, 93, 1) = 1))
#                :  :     +- FileScan text [value#42] Batched: false, DataFilters: [isnotnull(value#42), (substring(value#42, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2011 AS year#50, substring(value#48, 5, 6) AS usaf#2341, substring(value#48, 11, 5) AS wban#2342, (cast(cast(substring(value#48, 88, 5) as float) as double) / 10.0) AS air_temperature#2351]
#                :  :  +- Filter (isnotnull(value#48) AND (substring(value#48, 93, 1) = 1))
#                :  :     +- FileScan text [value#48] Batched: false, DataFilters: [isnotnull(value#48), (substring(value#48, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2012 AS year#56, substring(value#54, 5, 6) AS usaf#2353, substring(value#54, 11, 5) AS wban#2354, (cast(cast(substring(value#54, 88, 5) as float) as double) / 10.0) AS air_temperature#2363]
#                :  :  +- Filter (isnotnull(value#54) AND (substring(value#54, 93, 1) = 1))
#                :  :     +- FileScan text [value#54] Batched: false, DataFilters: [isnotnull(value#54), (substring(value#54, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2013 AS year#62, substring(value#60, 5, 6) AS usaf#2365, substring(value#60, 11, 5) AS wban#2366, (cast(cast(substring(value#60, 88, 5) as float) as double) / 10.0) AS air_temperature#2375]
#                :  :  +- Filter (isnotnull(value#60) AND (substring(value#60, 93, 1) = 1))
#                :  :     +- FileScan text [value#60] Batched: false, DataFilters: [isnotnull(value#60), (substring(value#60, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2014 AS year#68, substring(value#66, 5, 6) AS usaf#2377, substring(value#66, 11, 5) AS wban#2378, (cast(cast(substring(value#66, 88, 5) as float) as double) / 10.0) AS air_temperature#2387]
#                :  :  +- Filter (isnotnull(value#66) AND (substring(value#66, 93, 1) = 1))
#                :  :     +- FileScan text [value#66] Batched: false, DataFilters: [isnotnull(value#66), (substring(value#66, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2015 AS year#74, substring(value#72, 5, 6) AS usaf#2389, substring(value#72, 11, 5) AS wban#2390, (cast(cast(substring(value#72, 88, 5) as float) as double) / 10.0) AS air_temperature#2399]
#                :  :  +- Filter (isnotnull(value#72) AND (substring(value#72, 93, 1) = 1))
#                :  :     +- FileScan text [value#72] Batched: false, DataFilters: [isnotnull(value#72), (substring(value#72, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2016 AS year#80, substring(value#78, 5, 6) AS usaf#2401, substring(value#78, 11, 5) AS wban#2402, (cast(cast(substring(value#78, 88, 5) as float) as double) / 10.0) AS air_temperature#2411]
#                :  :  +- Filter (isnotnull(value#78) AND (substring(value#78, 93, 1) = 1))
#                :  :     +- FileScan text [value#78] Batched: false, DataFilters: [isnotnull(value#78), (substring(value#78, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2017 AS year#86, substring(value#84, 5, 6) AS usaf#2413, substring(value#84, 11, 5) AS wban#2414, (cast(cast(substring(value#84, 88, 5) as float) as double) / 10.0) AS air_temperature#2423]
#                :  :  +- Filter (isnotnull(value#84) AND (substring(value#84, 93, 1) = 1))
#                :  :     +- FileScan text [value#84] Batched: false, DataFilters: [isnotnull(value#84), (substring(value#84, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  :- Project [2018 AS year#92, substring(value#90, 5, 6) AS usaf#2425, substring(value#90, 11, 5) AS wban#2426, (cast(cast(substring(value#90, 88, 5) as float) as double) / 10.0) AS air_temperature#2435]
#                :  :  +- Filter (isnotnull(value#90) AND (substring(value#90, 93, 1) = 1))
#                :  :     +- FileScan text [value#90] Batched: false, DataFilters: [isnotnull(value#90), (substring(value#90, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                :  +- Project [2019 AS year#98, substring(value#96, 5, 6) AS usaf#2437, substring(value#96, 11, 5) AS wban#2438, (cast(cast(substring(value#96, 88, 5) as float) as double) / 10.0) AS air_temperature#2447]
#                :     +- Filter (isnotnull(value#96) AND (substring(value#96, 93, 1) = 1))
#                :        +- FileScan text [value#96] Batched: false, DataFilters: [isnotnull(value#96), (substring(value#96, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=4343]
#                   +- Filter (isnotnull(usaf#170) AND isnotnull(wban#171))
#                      +- FileScan csv [USAF#170,WBAN#171,CTRY#173] Batched: false, DataFilters: [isnotnull(USAF#170), isnotnull(WBAN#171)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string,CTRY:string>

# %% [markdown]
# ### Exercise
#
# Now implement a similar query, which only shows the years where the average temperature is higher than the overall average temperature. Note that you need to filter *after* the aggregation (in order to access the average per country and year).

# %%
query = """
    SELECT
        year,
        country,
        min(air_temperature) AS min_air_temperature,
        max(air_temperature) AS max_air_temperature,
        avg(air_temperature) AS avg_air_temperature
    FROM joined_weather
    WHERE air_temperature_qual = '1'
    GROUP BY year,country
    HAVING avg(air_temperature) > (SELECT avg(air_temperature) FROM joined_weather WHERE air_temperature_qual = '1')
"""

# Execute the query and display result
result = spark.sql(query)
result.toPandas()
# Out:
#      year country  min_air_temperature  max_air_temperature
# 0    2003      NL                -14.3                 36.0  \
# 1    2003      BE                -11.3                 36.3
# 2    2003      AU                -17.6                 37.4
# 3    2003      LU                -13.0                 37.4
# 4    2003      PO                 -2.0                 39.0
# ..    ...     ...                  ...                  ...
# 300  2019      SC                 21.0                 34.0
# 301  2019      CH                 13.0                 35.0
# 302  2019      AS                  2.7                 45.8
# 303  2019      SF                  2.7                 42.5
# 304  2019      IT                 10.0                 12.5
#
#      avg_air_temperature
# 0              10.847775
# 1              10.945630
# 2              10.012979
# 3              10.490859
# 4              15.615641
# ..                   ...
# 300            27.825143
# 301            27.250057
# 302            23.224927
# 303            20.635556
# 304            10.950000
#
# [305 rows x 5 columns]

# %% [markdown]
# ## 3.3 Correlated Subquery
#
# A special case of a scalar subquery is the *correlated subquery*, which performs its calculation dependent on values from the main query. For example, the following query calculates the overall average temperature per country and adds it as a separate column.

# %%
query = """
    SELECT
        w.year,
        w.country,
        w.air_temperature,
        (SELECT avg(w2.air_temperature) FROM joined_weather w2 WHERE w2.air_temperature_qual = '1' AND w2.country = w.country) AS avg_air_temperature_per_country
    FROM joined_weather w
    WHERE w.air_temperature_qual = '1'
"""

# Execute the query and display result
result = spark.sql(query)
result.limit(10).toPandas()
# Out:
#    year country  air_temperature  avg_air_temperature_per_country
# 0  2003      US             -2.0                        10.803672
# 1  2003      US              2.0                        10.803672
# 2  2003      US             -3.0                        10.803672
# 3  2003      US             -4.0                        10.803672
# 4  2003      US             -3.0                        10.803672
# 5  2003      US             -2.0                        10.803672
# 6  2003      US             -2.0                        10.803672
# 7  2003      US             -2.0                        10.803672
# 8  2003      US             -2.0                        10.803672
# 9  2003      US             -2.0                        10.803672

# %% [markdown]
# ### Execution Plan
#
# By looking at the execution plan, it becomes clear, that Spark transforms the correlated query into an equivalent query, which contains a grouped agreggregation followed by a join.

# %%
result.explain()
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [year#2, CTRY#173 AS country#461, air_temperature#224, avg(air_temperature)#4478 AS avg_air_temperature_per_country#4476]
#    +- SortMergeJoin [CTRY#173], [country#461#4950], LeftOuter
#       :- Sort [CTRY#173 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(CTRY#173, 200), ENSURE_REQUIREMENTS, [plan_id=11606]
#       :     +- Project [year#2, air_temperature#224, CTRY#173]
#       :        +- BroadcastHashJoin [usaf#214, wban#215], [usaf#170, wban#171], LeftOuter, BuildRight, false
#       :           :- Union
#       :           :  :- Project [2003 AS year#2, substring(value#0, 5, 6) AS usaf#214, substring(value#0, 11, 5) AS wban#215, (cast(cast(substring(value#0, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#       :           :  :  +- Filter (isnotnull(value#0) AND (substring(value#0, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#0] Batched: false, DataFilters: [isnotnull(value#0), (substring(value#0, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2004 AS year#8, substring(value#6, 5, 6) AS usaf#5143, substring(value#6, 11, 5) AS wban#5144, (cast(cast(substring(value#6, 88, 5) as float) as double) / 10.0) AS air_temperature#5153]
#       :           :  :  +- Filter (isnotnull(value#6) AND (substring(value#6, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#6] Batched: false, DataFilters: [isnotnull(value#6), (substring(value#6, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2005 AS year#14, substring(value#12, 5, 6) AS usaf#5155, substring(value#12, 11, 5) AS wban#5156, (cast(cast(substring(value#12, 88, 5) as float) as double) / 10.0) AS air_temperature#5165]
#       :           :  :  +- Filter (isnotnull(value#12) AND (substring(value#12, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#12] Batched: false, DataFilters: [isnotnull(value#12), (substring(value#12, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2006 AS year#20, substring(value#18, 5, 6) AS usaf#5167, substring(value#18, 11, 5) AS wban#5168, (cast(cast(substring(value#18, 88, 5) as float) as double) / 10.0) AS air_temperature#5177]
#       :           :  :  +- Filter (isnotnull(value#18) AND (substring(value#18, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#18] Batched: false, DataFilters: [isnotnull(value#18), (substring(value#18, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2007 AS year#26, substring(value#24, 5, 6) AS usaf#5179, substring(value#24, 11, 5) AS wban#5180, (cast(cast(substring(value#24, 88, 5) as float) as double) / 10.0) AS air_temperature#5189]
#       :           :  :  +- Filter (isnotnull(value#24) AND (substring(value#24, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#24] Batched: false, DataFilters: [isnotnull(value#24), (substring(value#24, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2008 AS year#32, substring(value#30, 5, 6) AS usaf#5191, substring(value#30, 11, 5) AS wban#5192, (cast(cast(substring(value#30, 88, 5) as float) as double) / 10.0) AS air_temperature#5201]
#       :           :  :  +- Filter (isnotnull(value#30) AND (substring(value#30, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#30] Batched: false, DataFilters: [isnotnull(value#30), (substring(value#30, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2009 AS year#38, substring(value#36, 5, 6) AS usaf#5203, substring(value#36, 11, 5) AS wban#5204, (cast(cast(substring(value#36, 88, 5) as float) as double) / 10.0) AS air_temperature#5213]
#       :           :  :  +- Filter (isnotnull(value#36) AND (substring(value#36, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#36] Batched: false, DataFilters: [isnotnull(value#36), (substring(value#36, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2010 AS year#44, substring(value#42, 5, 6) AS usaf#5215, substring(value#42, 11, 5) AS wban#5216, (cast(cast(substring(value#42, 88, 5) as float) as double) / 10.0) AS air_temperature#5225]
#       :           :  :  +- Filter (isnotnull(value#42) AND (substring(value#42, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#42] Batched: false, DataFilters: [isnotnull(value#42), (substring(value#42, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2011 AS year#50, substring(value#48, 5, 6) AS usaf#5227, substring(value#48, 11, 5) AS wban#5228, (cast(cast(substring(value#48, 88, 5) as float) as double) / 10.0) AS air_temperature#5237]
#       :           :  :  +- Filter (isnotnull(value#48) AND (substring(value#48, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#48] Batched: false, DataFilters: [isnotnull(value#48), (substring(value#48, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2012 AS year#56, substring(value#54, 5, 6) AS usaf#5239, substring(value#54, 11, 5) AS wban#5240, (cast(cast(substring(value#54, 88, 5) as float) as double) / 10.0) AS air_temperature#5249]
#       :           :  :  +- Filter (isnotnull(value#54) AND (substring(value#54, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#54] Batched: false, DataFilters: [isnotnull(value#54), (substring(value#54, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2013 AS year#62, substring(value#60, 5, 6) AS usaf#5251, substring(value#60, 11, 5) AS wban#5252, (cast(cast(substring(value#60, 88, 5) as float) as double) / 10.0) AS air_temperature#5261]
#       :           :  :  +- Filter (isnotnull(value#60) AND (substring(value#60, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#60] Batched: false, DataFilters: [isnotnull(value#60), (substring(value#60, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2014 AS year#68, substring(value#66, 5, 6) AS usaf#5263, substring(value#66, 11, 5) AS wban#5264, (cast(cast(substring(value#66, 88, 5) as float) as double) / 10.0) AS air_temperature#5273]
#       :           :  :  +- Filter (isnotnull(value#66) AND (substring(value#66, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#66] Batched: false, DataFilters: [isnotnull(value#66), (substring(value#66, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2015 AS year#74, substring(value#72, 5, 6) AS usaf#5275, substring(value#72, 11, 5) AS wban#5276, (cast(cast(substring(value#72, 88, 5) as float) as double) / 10.0) AS air_temperature#5285]
#       :           :  :  +- Filter (isnotnull(value#72) AND (substring(value#72, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#72] Batched: false, DataFilters: [isnotnull(value#72), (substring(value#72, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2016 AS year#80, substring(value#78, 5, 6) AS usaf#5287, substring(value#78, 11, 5) AS wban#5288, (cast(cast(substring(value#78, 88, 5) as float) as double) / 10.0) AS air_temperature#5297]
#       :           :  :  +- Filter (isnotnull(value#78) AND (substring(value#78, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#78] Batched: false, DataFilters: [isnotnull(value#78), (substring(value#78, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2017 AS year#86, substring(value#84, 5, 6) AS usaf#5299, substring(value#84, 11, 5) AS wban#5300, (cast(cast(substring(value#84, 88, 5) as float) as double) / 10.0) AS air_temperature#5309]
#       :           :  :  +- Filter (isnotnull(value#84) AND (substring(value#84, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#84] Batched: false, DataFilters: [isnotnull(value#84), (substring(value#84, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  :- Project [2018 AS year#92, substring(value#90, 5, 6) AS usaf#5311, substring(value#90, 11, 5) AS wban#5312, (cast(cast(substring(value#90, 88, 5) as float) as double) / 10.0) AS air_temperature#5321]
#       :           :  :  +- Filter (isnotnull(value#90) AND (substring(value#90, 93, 1) = 1))
#       :           :  :     +- FileScan text [value#90] Batched: false, DataFilters: [isnotnull(value#90), (substring(value#90, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           :  +- Project [2019 AS year#98, substring(value#96, 5, 6) AS usaf#5323, substring(value#96, 11, 5) AS wban#5324, (cast(cast(substring(value#96, 88, 5) as float) as double) / 10.0) AS air_temperature#5333]
#       :           :     +- Filter (isnotnull(value#96) AND (substring(value#96, 93, 1) = 1))
#       :           :        +- FileScan text [value#96] Batched: false, DataFilters: [isnotnull(value#96), (substring(value#96, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#       :           +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=11594]
#       :              +- Filter (isnotnull(usaf#170) AND isnotnull(wban#171))
#       :                 +- FileScan csv [USAF#170,WBAN#171,CTRY#173] Batched: false, DataFilters: [isnotnull(USAF#170), isnotnull(WBAN#171)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN)], ReadSchema: struct<USAF:string,WBAN:string,CTRY:string>
#       +- Sort [country#461#4950 ASC NULLS FIRST], false, 0
#          +- HashAggregate(keys=[country#461], functions=[avg(air_temperature#224)])
#             +- Exchange hashpartitioning(country#461, 200), ENSURE_REQUIREMENTS, [plan_id=11602]
#                +- HashAggregate(keys=[country#461], functions=[partial_avg(air_temperature#224)])
#                   +- Project [air_temperature#224, CTRY#4499 AS country#461]
#                      +- BroadcastHashJoin [usaf#214, wban#215], [usaf#4496, wban#4497], Inner, BuildRight, false
#                         :- Union
#                         :  :- Project [substring(value#4479, 5, 6) AS usaf#214, substring(value#4479, 11, 5) AS wban#215, (cast(cast(substring(value#4479, 88, 5) as float) as double) / 10.0) AS air_temperature#224]
#                         :  :  +- Filter (isnotnull(value#4479) AND (substring(value#4479, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4479] Batched: false, DataFilters: [isnotnull(value#4479), (substring(value#4479, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2003], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4480, 5, 6) AS usaf#4951, substring(value#4480, 11, 5) AS wban#4952, (cast(cast(substring(value#4480, 88, 5) as float) as double) / 10.0) AS air_temperature#4961]
#                         :  :  +- Filter (isnotnull(value#4480) AND (substring(value#4480, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4480] Batched: false, DataFilters: [isnotnull(value#4480), (substring(value#4480, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2004], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4481, 5, 6) AS usaf#4963, substring(value#4481, 11, 5) AS wban#4964, (cast(cast(substring(value#4481, 88, 5) as float) as double) / 10.0) AS air_temperature#4973]
#                         :  :  +- Filter (isnotnull(value#4481) AND (substring(value#4481, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4481] Batched: false, DataFilters: [isnotnull(value#4481), (substring(value#4481, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2005], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4482, 5, 6) AS usaf#4975, substring(value#4482, 11, 5) AS wban#4976, (cast(cast(substring(value#4482, 88, 5) as float) as double) / 10.0) AS air_temperature#4985]
#                         :  :  +- Filter (isnotnull(value#4482) AND (substring(value#4482, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4482] Batched: false, DataFilters: [isnotnull(value#4482), (substring(value#4482, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2006], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4483, 5, 6) AS usaf#4987, substring(value#4483, 11, 5) AS wban#4988, (cast(cast(substring(value#4483, 88, 5) as float) as double) / 10.0) AS air_temperature#4997]
#                         :  :  +- Filter (isnotnull(value#4483) AND (substring(value#4483, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4483] Batched: false, DataFilters: [isnotnull(value#4483), (substring(value#4483, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2007], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4484, 5, 6) AS usaf#4999, substring(value#4484, 11, 5) AS wban#5000, (cast(cast(substring(value#4484, 88, 5) as float) as double) / 10.0) AS air_temperature#5009]
#                         :  :  +- Filter (isnotnull(value#4484) AND (substring(value#4484, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4484] Batched: false, DataFilters: [isnotnull(value#4484), (substring(value#4484, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2008], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4485, 5, 6) AS usaf#5011, substring(value#4485, 11, 5) AS wban#5012, (cast(cast(substring(value#4485, 88, 5) as float) as double) / 10.0) AS air_temperature#5021]
#                         :  :  +- Filter (isnotnull(value#4485) AND (substring(value#4485, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4485] Batched: false, DataFilters: [isnotnull(value#4485), (substring(value#4485, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2009], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4486, 5, 6) AS usaf#5023, substring(value#4486, 11, 5) AS wban#5024, (cast(cast(substring(value#4486, 88, 5) as float) as double) / 10.0) AS air_temperature#5033]
#                         :  :  +- Filter (isnotnull(value#4486) AND (substring(value#4486, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4486] Batched: false, DataFilters: [isnotnull(value#4486), (substring(value#4486, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2010], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4487, 5, 6) AS usaf#5035, substring(value#4487, 11, 5) AS wban#5036, (cast(cast(substring(value#4487, 88, 5) as float) as double) / 10.0) AS air_temperature#5045]
#                         :  :  +- Filter (isnotnull(value#4487) AND (substring(value#4487, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4487] Batched: false, DataFilters: [isnotnull(value#4487), (substring(value#4487, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2011], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4488, 5, 6) AS usaf#5047, substring(value#4488, 11, 5) AS wban#5048, (cast(cast(substring(value#4488, 88, 5) as float) as double) / 10.0) AS air_temperature#5057]
#                         :  :  +- Filter (isnotnull(value#4488) AND (substring(value#4488, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4488] Batched: false, DataFilters: [isnotnull(value#4488), (substring(value#4488, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2012], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4489, 5, 6) AS usaf#5059, substring(value#4489, 11, 5) AS wban#5060, (cast(cast(substring(value#4489, 88, 5) as float) as double) / 10.0) AS air_temperature#5069]
#                         :  :  +- Filter (isnotnull(value#4489) AND (substring(value#4489, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4489] Batched: false, DataFilters: [isnotnull(value#4489), (substring(value#4489, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2013], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4490, 5, 6) AS usaf#5071, substring(value#4490, 11, 5) AS wban#5072, (cast(cast(substring(value#4490, 88, 5) as float) as double) / 10.0) AS air_temperature#5081]
#                         :  :  +- Filter (isnotnull(value#4490) AND (substring(value#4490, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4490] Batched: false, DataFilters: [isnotnull(value#4490), (substring(value#4490, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2014], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4491, 5, 6) AS usaf#5083, substring(value#4491, 11, 5) AS wban#5084, (cast(cast(substring(value#4491, 88, 5) as float) as double) / 10.0) AS air_temperature#5093]
#                         :  :  +- Filter (isnotnull(value#4491) AND (substring(value#4491, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4491] Batched: false, DataFilters: [isnotnull(value#4491), (substring(value#4491, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2015], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4492, 5, 6) AS usaf#5095, substring(value#4492, 11, 5) AS wban#5096, (cast(cast(substring(value#4492, 88, 5) as float) as double) / 10.0) AS air_temperature#5105]
#                         :  :  +- Filter (isnotnull(value#4492) AND (substring(value#4492, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4492] Batched: false, DataFilters: [isnotnull(value#4492), (substring(value#4492, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2016], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4493, 5, 6) AS usaf#5107, substring(value#4493, 11, 5) AS wban#5108, (cast(cast(substring(value#4493, 88, 5) as float) as double) / 10.0) AS air_temperature#5117]
#                         :  :  +- Filter (isnotnull(value#4493) AND (substring(value#4493, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4493] Batched: false, DataFilters: [isnotnull(value#4493), (substring(value#4493, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2017], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  :- Project [substring(value#4494, 5, 6) AS usaf#5119, substring(value#4494, 11, 5) AS wban#5120, (cast(cast(substring(value#4494, 88, 5) as float) as double) / 10.0) AS air_temperature#5129]
#                         :  :  +- Filter (isnotnull(value#4494) AND (substring(value#4494, 93, 1) = 1))
#                         :  :     +- FileScan text [value#4494] Batched: false, DataFilters: [isnotnull(value#4494), (substring(value#4494, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2018], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         :  +- Project [substring(value#4495, 5, 6) AS usaf#5131, substring(value#4495, 11, 5) AS wban#5132, (cast(cast(substring(value#4495, 88, 5) as float) as double) / 10.0) AS air_temperature#5141]
#                         :     +- Filter (isnotnull(value#4495) AND (substring(value#4495, 93, 1) = 1))
#                         :        +- FileScan text [value#4495] Batched: false, DataFilters: [isnotnull(value#4495), (substring(value#4495, 93, 1) = 1)], Format: Text, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/2019], PartitionFilters: [], PushedFilters: [IsNotNull(value)], ReadSchema: struct<value:string>
#                         +- BroadcastExchange HashedRelationBroadcastMode(List(input[0, string, false], input[1, string, false]),false), [plan_id=11597]
#                            +- Filter ((isnotnull(usaf#4496) AND isnotnull(wban#4497)) AND isnotnull(CTRY#4499))
#                               +- FileScan csv [USAF#4496,WBAN#4497,CTRY#4499] Batched: false, DataFilters: [isnotnull(USAF#4496), isnotnull(WBAN#4497), isnotnull(CTRY#4499)], Format: CSV, Location: InMemoryFileIndex(1 paths)[file:/dimajix/data/weather-noaa-sample/isd-history], PartitionFilters: [], PushedFilters: [IsNotNull(USAF), IsNotNull(WBAN), IsNotNull(CTRY)], ReadSchema: struct<USAF:string,WBAN:string,CTRY:string>

# %% [markdown]
# ### Exercise
#
# Now add a column containing the maximum temperature over all weather stations of the current year.

# %%
query = """
    SELECT
        w.year,
        w.country,
        w.air_temperature,
        (SELECT max(w2.air_temperature) FROM joined_weather w2 WHERE w2.air_temperature_qual = '1' AND w2.year = w.year) AS max_air_temperature_per_year
    FROM joined_weather w
    WHERE w.air_temperature_qual = '1'
"""

# Execute the query and display result
result = spark.sql(query)
result.limit(10).toPandas()
# Out:
#    year country  air_temperature  max_air_temperature_per_year
# 0  2003      US             -2.0                          45.8
# 1  2003      US              2.0                          45.8
# 2  2003      US             -3.0                          45.8
# 3  2003      US             -4.0                          45.8
# 4  2003      US             -3.0                          45.8
# 5  2003      US             -2.0                          45.8
# 6  2003      US             -2.0                          45.8
# 7  2003      US             -2.0                          45.8
# 8  2003      US             -2.0                          45.8
# 9  2003      US             -2.0                          45.8

# %% [markdown]
# # 4.0 Common Table Expression
#
# The following section will provide an SQL query, which essentially performs the very same calculation. But we implement all steps within a single query using *Common Table Expressions*, CTEs. A CTE can be seen as a local temp view, which is locally scoped to be only accessible within a single query. Therefore, a CTE can be interpreted as some sort of *table valued function* (but without a parameter).

# %% [markdown]
# ## 4.1 Air Temperature
#
# In order to provide an instructive example, let's start with a simpler query which only calculates the metrics related to the air temperature.

# %%
query = """
-- Extract measurements
WITH weather AS (
    SELECT
        year,
        substring(value,5,6) AS usaf,
        substring(value,11,5) AS wban,
        substring(value,16,8) AS `date`,
        substring(value,24,4) AS `time`,
        substring(value,42,5) AS report_type,
        substring(value,61,3) AS wind_direction,
        substring(value,64,1) AS wind_direction_qual,
        substring(value,65,1) AS wind_observation,
        CAST(substring(value,66,4) AS FLOAT) / 10.0 AS wind_speed,
        substring(value,70,1) AS wind_speed_qual,
        CAST(substring(value,88,5) AS FLOAT) / 10.0 AS air_temperature,
        substring(value,93,1) AS air_temperature_qual
    FROM raw_weather
),
-- Join measurements and master data
joined_weather AS (
    SELECT
        weather.*,
        CTRY AS country
    FROM weather
    LEFT JOIN stations ON weather.usaf = stations.usaf AND weather.wban = stations.wban
)
-- Calculate min/max/avg air temperature per county and year
SELECT
    year,
    country,
    min(air_temperature) AS min_air_temperature,
    max(air_temperature) AS max_air_temperature,
    avg(air_temperature) AS avg_air_temperature
FROM joined_weather
WHERE air_temperature_qual = '1'
GROUP BY year,country
"""

# Execute the query and display result
result = spark.sql(query)
result.toPandas()
# Out:
#      year country  min_air_temperature  max_air_temperature
# 0    2003      NL                -14.3                 36.0  \
# 1    2003      US                -44.0                 41.0
# 2    2003      BE                -11.3                 36.3
# 3    2003      AU                -17.6                 37.4
# 4    2003      EZ                -16.0                 37.0
# ..    ...     ...                  ...                  ...
# 478  2019      CH                 13.0                 35.0
# 479  2019      AS                  2.7                 45.8
# 480  2019      SF                  2.7                 42.5
# 481  2019      RS                -25.9                 29.9
# 482  2019      IT                 10.0                 12.5
#
#      avg_air_temperature
# 0              10.847775
# 1               6.856936
# 2              10.945630
# 3              10.012979
# 4               8.918003
# ..                   ...
# 478            27.250057
# 479            23.224927
# 480            20.635556
# 481             4.778747
# 482            10.950000
#
# [483 rows x 5 columns]

# %% [markdown]
# ## 4.2 Full Query
#
# In the next and final step, we construct a more complicated query, which also calculates the wind speed metrics and which performs the final join between the wind speed and air temperature metrics.

# %%
query = """
-- Extract measurements
WITH weather AS (
    SELECT
        year,
        substring(value,5,6) AS usaf,
        substring(value,11,5) AS wban,
        substring(value,16,8) AS `date`,
        substring(value,24,4) AS `time`,
        substring(value,42,5) AS report_type,
        substring(value,61,3) AS wind_direction,
        substring(value,64,1) AS wind_direction_qual,
        substring(value,65,1) AS wind_observation,
        CAST(substring(value,66,4) AS FLOAT) / 10.0 AS wind_speed,
        substring(value,70,1) AS wind_speed_qual,
        CAST(substring(value,88,5) AS FLOAT) / 10.0 AS air_temperature,
        substring(value,93,1) AS air_temperature_qual
    FROM raw_weather
),
-- Join measurements and master data
joined_weather AS (
    SELECT
        weather.*,
        CTRY AS country
    FROM weather
    LEFT JOIN stations ON weather.usaf = stations.usaf AND weather.wban = stations.wban
),
-- Aggregate air temperature
year_country_temperature AS (
    SELECT
        year,
        country,
        min(air_temperature) AS min_air_temperature,
        max(air_temperature) AS max_air_temperature,
        avg(air_temperature) AS avg_air_temperature
    FROM joined_weather
    WHERE air_temperature_qual = '1'
    GROUP BY year,country
),
-- Aggregate wind speed
year_country_wind AS (
    SELECT
        year,
        country,
        min(wind_speed) AS min_wind_speed,
        max(wind_speed) AS max_wind_speed,
        avg(air_temperature) AS avg_wind_speed
    FROM joined_weather
    WHERE wind_speed_qual = '1'
    GROUP BY year,country
)
-- Join aggeragted wind speed and aggregated air temperature
SELECT
    COALESCE(wind.year, temp.year) AS year,
    COALESCE(wind.country, temp.country) AS country,
    wind.min_wind_speed,
    wind.max_wind_speed,
    wind.avg_wind_speed,
    temp.min_air_temperature,
    temp.max_air_temperature,
    temp.avg_air_temperature
FROM year_country_wind wind
FULL OUTER JOIN year_country_temperature temp ON wind.year = temp.year AND wind.country = temp.country
"""

# Execute the query and display result
result = spark.sql(query)
result.toPandas()
# Out:
#      year country  min_wind_speed  max_wind_speed  avg_wind_speed
# 0    2003      AS             0.0            14.4       24.965552  \
# 1    2003      AU             0.0            22.6       34.653486
# 2    2003      BE             0.0            19.0       20.184212
# 3    2003      CA             0.0            27.8      118.253679
# 4    2003      DA             0.0            23.0       15.369517
# ..    ...     ...             ...             ...             ...
# 480  2019      SF             0.0            10.8       37.555696
# 481  2019      SV             0.0            32.0       -4.371690
# 482  2019      SW             0.0            20.0        4.055555
# 483  2019      UK             0.0            17.0       11.209918
# 484  2019      US             0.0            25.2       14.394539
#
#      min_air_temperature  max_air_temperature  avg_air_temperature
# 0                    0.3                 45.8            23.025439
# 1                  -17.6                 37.4            10.012979
# 2                  -11.3                 36.3            10.945630
# 3                  -40.1                 35.8             1.453475
# 4                  -16.0                 30.0             8.552005
# ..                   ...                  ...                  ...
# 480                  2.7                 42.5            20.635556
# 481                -36.2                 16.0            -4.632360
# 482                -39.3                 29.3             2.710664
# 483                 -7.2                 35.0            11.100897
# 484                -47.8                 41.7            10.417694
#
# [485 rows x 8 columns]
